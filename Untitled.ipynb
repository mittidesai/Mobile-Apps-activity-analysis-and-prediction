# %%
import utils
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from sklearn import tree, model_selection
import seaborn as sns

df = pd.read_csv("Duration_analysis_SquarePanda.csv", error_bad_lines=False)

# %%
df.describe
# Out:
# <bound method DataFrame.describe of      childid  age  Total_Duration_mins  Average_Duration_mins
# 0        401    7              55.2000              13.800000
# 1        196    5              48.6000               9.720000
# 2       2303    4              45.0000               1.451613
# 3       2918    5               3.1667               0.791667
# 4       2312   10              27.8333               1.030864
# 5       1223   22              24.2333               0.692381
# 6       3033   16               0.4667               0.466667
# 7        383    3              56.8833              14.220833
# 8       3667    3               0.6333               0.211111
# 9       3048   16               0.4167               0.037879
# 10      1255   21               0.5667               0.056667
# 11      3406   18               0.2833               0.283333
# 12      1973    3               2.9667               0.114103
# 13      1393    2               1.0833               0.216667
# 14      2359    0               5.4667               0.044086
# 15      1303    5              19.0667               0.052525
# 16      3145    5               4.3333               0.120370
# 17      3786    4               0.5833               0.072917
# 18       756    5               0.2167               0.108333
# 19      2907    5               0.2333               0.116667
# 20      3262    1               0.3667               0.183333
# 21      3292    5               0.2667               0.133333
# 22      2830    7               1.1000               0.047826
# 23      1728    3               4.3167               0.036895
# 24      3099    4               0.4833               0.161111
# 25      1812    5              11.1833               0.058551
# 26      1745    7               0.1833               0.061111
# 27      2452    7               0.4500               0.040909
# 28      1222    7               1.3167               0.119697
# 29      2453    6               0.6667               0.018519
# ...      ...  ...                  ...                    ...
# 2716    2765    5               0.5833               0.014583
# 2717    3425    4               0.2167               0.008667
# 2718    3644    6               0.2833               0.015741
# 2719    3597    6               0.2000               0.016667
# 2720    2422    6               0.1000               0.012500
# 2721    2393    6               0.1500               0.007500
# 2722    1922    4               0.0833               0.016667
# 2723    2095    7               1.4500               0.013303
# 2724    3590    9               0.7000               0.010937
# 2725    1180    4              25.3833               1.269167
# 2726    3578    8               1.2500               0.017361
# 2727     948    7               0.5000               0.011905
# 2728    1025    4               1.6000               0.012903
# 2729    3392   16               0.5167               0.008908
# 2730     515   11               0.0000               0.000000
# 2731    3137    6               0.2500               0.014706
# 2732    3465    5               0.1333               0.008889
# 2733    2374    3               0.8000               0.016327
# 2734     874    4               4.2500               0.027597
# 2735    2263    2               0.0333               0.004167
# 2736     954    8               0.1667               0.009804
# 2737     704    7               2.2667               0.043590
# 2738     193    5               0.2500               0.031250
# 2739    3129    8               0.0167               0.002083
# 2740    2040    8               2.4333               0.017892
# 2741    3613    4               0.0333               0.002083
# 2742     408    6               0.2000               0.011111
# 2743    1191    6               0.0333               0.011111
# 2744    1451   10               0.8667               0.017333
# 2745    2075    8               0.3667               0.008527
#
# [2746 rows x 4 columns]>

# %%
import matplotlib
matplotlib.style.use('ggplot')
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

ts = ts.cumsum()
ts.plot()
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x=df['age']
y=df['Total_Duration_mins']
plt.scatter(x,y,color='c')
plt.title('Age v/s Total Duration')
plt.xlabel('Age')
plt.ylabel('Total Duration')
plt.show()

# %% [markdown]
# ### Maximum population belongs to the age range 0-10 and Total Duration belongs to the range of 0-200 mins

# %%
from matplotlib import pyplot as plt
from matplotlib import style
style.use('ggplot')
x1=df['age']
y1=df['Average_Duration_mins']

plt.scatter(x1,y1,color='g')
plt.title('Age v/s Average Duration')
plt.xlabel('Age')
plt.ylabel('Average Duration')
plt.show()

# %% [markdown]
# ### Maximum population belongs to the age range 0-10 and Average Duration belongs to the range of 0-5 mins

# %%
import matplotlib.pyplot as plt
import numpy as np

y_stack = np.row_stack((df['Average_Duration_mins'],df['Total_Duration_mins'])) 
builds=df['age']
fig = plt.figure(figsize=(11,8))
ax1 = fig.add_subplot(111)

ax1.plot(builds, y_stack[0,:], label='Component 1', color='c', marker='o')
ax1.plot(builds, y_stack[1,:], label='Component 2', color='g', marker='o')


handles, labels = ax1.get_legend_handles_labels()
lgd = ax1.legend(handles, labels, loc='upper center', bbox_to_anchor=(1.15,1))
ax1.grid('on')
plt.show()
plt.savefig('smooth_plot.png')
