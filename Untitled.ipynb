# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sb
from patsy import dmatrices
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

# %matplotlib inline

df = pd.read_csv("Sessionized_SquarePanda.csv",parse_dates=True,error_bad_lines=False)
df.head()
# Out:
# /home/miti/.local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#
# Bad key "patch.force_edgecolor" on line 33 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashed_pattern" on line 18 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markeredgecolor" on line 369 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.second" on line 235 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.right" on line 271 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.month" on line 231 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "scatter.marker" on line 345 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.right" on line 273 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.major.left" on line 270 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.left" on line 258 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.bottom" on line 256 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.autolimit_mode" on line 220 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.color" on line 37 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.marker" on line 367 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.minute" on line 234 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.top" on line 253 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.day" on line 232 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.right" on line 259 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.bottom" on line 242 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.microsecond" on line 236 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hist.bins" on line 40 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.scale_dashes" on line 21 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.titlepad" on line 184 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "_internal.classic_mode" on line 526 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.hour" on line 233 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markerfacecolor" on line 368 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "date.autoformatter.year" on line 230 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/__init__.py:1076: UserWarning: Bad val "auto" on line #360
# 	"boxplot.flierprops.markerfacecolor: auto
# "
# 	in file "/home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle"
# 	Key boxplot.flierprops.markerfacecolor: auto does not look like a color arg
#   (val, error_details, msg))
#
# Bad key "lines.dotted_pattern" on line 20 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "axes.formatter.offset_threshold" on line 207 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.minor.top" on line 255 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.minor.left" on line 272 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "lines.dashdot_pattern" on line 19 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.major.bottom" on line 254 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "boxplot.meanprops.markersize" on line 370 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "hatch.linewidth" on line 38 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "xtick.top" on line 241 in
# /home/miti/.local/lib/python2.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
# /home/miti/.local/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
# /home/miti/.local/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
#    childid  session_id            createdat gamename  duration gender  age  \
# 0     1004           0  2016-11-07 20:34:00   Lagoon        47      F   19
# 1     1005           0  2016-11-07 20:52:00   Lagoon         7      F    7
# 2     1005           0  2016-11-07 20:53:00   Lagoon         0      F    7
# 3     1005           0  2016-11-07 20:54:00   Lagoon         0      F    7
# 4     1010           0  2016-11-08 00:45:00  Bubbles        70      F    4
#
#   wordtype   platform  gamescore  minutes_since_last_interval  \
# 0     WORD  Not Known          1                          NaN
# 1     WORD  Not Known          1                          NaN
# 2     WORD  Not Known          1                          1.0
# 3     WORD  Not Known          1                          1.0
# 4     WORD  Not Known          1                          NaN
#
#    new_event_boundary
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
df['dayofweek'] = pd.to_datetime(df['createdat']).dt.dayofweek
#df_1 = df.groupby('childid')
#df_1.describe()

# %% [raw]
# df['dayofweek'] = pd.to_datetime(df['createdat']).dt.dayofweek
# df_1 = df.groupby('childid')
# df_1.describe()

# %%
#df_1.dayofweek.hist()
# Out:
# childid
# 183     Axes(0.125,0.125;0.775x0.775)
# 188     Axes(0.125,0.125;0.775x0.775)
# 189     Axes(0.125,0.125;0.775x0.775)
# 191     Axes(0.125,0.125;0.775x0.775)
# 193     Axes(0.125,0.125;0.775x0.775)
# 194     Axes(0.125,0.125;0.775x0.775)
# 196     Axes(0.125,0.125;0.775x0.775)
# 197     Axes(0.125,0.125;0.775x0.775)
# 198     Axes(0.125,0.125;0.775x0.775)
# 199     Axes(0.125,0.125;0.775x0.775)
# 200     Axes(0.125,0.125;0.775x0.775)
# 202     Axes(0.125,0.125;0.775x0.775)
# 203     Axes(0.125,0.125;0.775x0.775)
# 204     Axes(0.125,0.125;0.775x0.775)
# 205     Axes(0.125,0.125;0.775x0.775)
# 206     Axes(0.125,0.125;0.775x0.775)
# 211     Axes(0.125,0.125;0.775x0.775)
# 214     Axes(0.125,0.125;0.775x0.775)
# 215     Axes(0.125,0.125;0.775x0.775)
# 218     Axes(0.125,0.125;0.775x0.775)
# 219     Axes(0.125,0.125;0.775x0.775)
# 220     Axes(0.125,0.125;0.775x0.775)
# 229     Axes(0.125,0.125;0.775x0.775)
# 230     Axes(0.125,0.125;0.775x0.775)
# 232     Axes(0.125,0.125;0.775x0.775)
# 233     Axes(0.125,0.125;0.775x0.775)
# 234     Axes(0.125,0.125;0.775x0.775)
# 237     Axes(0.125,0.125;0.775x0.775)
# 238     Axes(0.125,0.125;0.775x0.775)
# 246     Axes(0.125,0.125;0.775x0.775)
#                     ...
# 3914    Axes(0.125,0.125;0.775x0.775)
# 3915    Axes(0.125,0.125;0.775x0.775)
# 3916    Axes(0.125,0.125;0.775x0.775)
# 3917    Axes(0.125,0.125;0.775x0.775)
# 3918    Axes(0.125,0.125;0.775x0.775)
# 3919    Axes(0.125,0.125;0.775x0.775)
# 3920    Axes(0.125,0.125;0.775x0.775)
# 3921    Axes(0.125,0.125;0.775x0.775)
# 3922    Axes(0.125,0.125;0.775x0.775)
# 3923    Axes(0.125,0.125;0.775x0.775)
# 3924    Axes(0.125,0.125;0.775x0.775)
# 3925    Axes(0.125,0.125;0.775x0.775)
# 3927    Axes(0.125,0.125;0.775x0.775)
# 3928    Axes(0.125,0.125;0.775x0.775)
# 3929    Axes(0.125,0.125;0.775x0.775)
# 3930    Axes(0.125,0.125;0.775x0.775)
# 3931    Axes(0.125,0.125;0.775x0.775)
# 3934    Axes(0.125,0.125;0.775x0.775)
# 3935    Axes(0.125,0.125;0.775x0.775)
# 3936    Axes(0.125,0.125;0.775x0.775)
# 3937    Axes(0.125,0.125;0.775x0.775)
# 3938    Axes(0.125,0.125;0.775x0.775)
# 3939    Axes(0.125,0.125;0.775x0.775)
# 3940    Axes(0.125,0.125;0.775x0.775)
# 3942    Axes(0.125,0.125;0.775x0.775)
# 3943    Axes(0.125,0.125;0.775x0.775)
# 3944    Axes(0.125,0.125;0.775x0.775)
# 3945    Axes(0.125,0.125;0.775x0.775)
# 3946    Axes(0.125,0.125;0.775x0.775)
# 3947    Axes(0.125,0.125;0.775x0.775)
# Name: dayofweek, Length: 2745, dtype: object

# %%
y, X = dmatrices('childid ~ dayofweek',
                  df, return_type="dataframe")
print X.columns
model = LogisticRegression(solver='sag')
# Out:
# Index([u'Intercept', u'dayofweek'], dtype='object')

# %%
model.fit(X,y)
# Out:
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/sag.py:286: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-db8ed034fc79> in <module>()
# ----> 1 model.fit(X,y)
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1239                       max_squared_sum=max_squared_sum,
#    1240                       sample_weight=sample_weight)
# -> 1241             for (class_, warm_start_coef_) in zip(classes_, warm_start_coef))
#    1242
#    1243         fold_coefs_, _, n_iter_ = zip(*fold_coefs_)
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     756             # was dispatched. In particular this covers the edge
#     757             # case of Parallel used with an exhausted iterator.
# --> 758             while self.dispatch_one_batch(iterator):
#     759                 self._iterating = True
#     760             else:
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in dispatch_one_batch(self, iterator)
#     606                 return False
#     607             else:
# --> 608                 self._dispatch(tasks)
#     609                 return True
#     610
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _dispatch(self, batch)
#     569         dispatch_timestamp = time.time()
#     570         cb = BatchCompletionCallBack(dispatch_timestamp, len(batch), self)
# --> 571         job = self._backend.apply_async(batch, callback=cb)
#     572         self._jobs.append(job)
#     573
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in apply_async(self, func, callback)
#     107     def apply_async(self, func, callback=None):
#     108         """Schedule a func to be run"""
# --> 109         result = ImmediateResult(func)
#     110         if callback:
#     111             callback(result)
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/_parallel_backends.pyc in __init__(self, batch)
#     324         # Don't delay the application, to avoid keeping the input
#     325         # arguments in memory
# --> 326         self.results = batch()
#     327
#     328     def get(self):
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self)
#     129
#     130     def __call__(self):
# --> 131         return [func(*args, **kwargs) for func, args, kwargs in self.items]
#     132
#     133     def __len__(self):
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, copy, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight)
#     744             w0, n_iter_i, warm_start_sag = sag_solver(
#     745                 X, target, sample_weight, loss, 1. / C, max_iter, tol,
# --> 746                 verbose, random_state, False, max_squared_sum, warm_start_sag)
#     747
#     748         else:
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/sag.pyc in sag_solver(X, y, sample_weight, loss, alpha, max_iter, tol, verbose, random_state, check_input, max_squared_sum, warm_start_mem)
#     281                             intercept_sum_gradient,
#     282                             intercept_decay,
# --> 283                             verbose)
#     284     if n_iter_ == max_iter:
#     285         warnings.warn("The max_iter was reached which means "
#
# KeyboardInterrupt:

# %%
model.score(X,y)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-5-e73869601626> in <module>()
# ----> 1 model.score(X,y)
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/base.pyc in score(self, X, y, sample_weight)
#     347         """
#     348         from .metrics import accuracy_score
# --> 349         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     350
#     351
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in predict(self, X)
#     334             Predicted class label per sample.
#     335         """
# --> 336         scores = self.decision_function(X)
#     337         if len(scores.shape) == 1:
#     338             indices = (scores > 0).astype(np.int)
#
# /home/miti/.local/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in decision_function(self, X)
#     318
#     319         scores = safe_sparse_dot(X, self.coef_.T,
# --> 320                                  dense_output=True) + self.intercept_
#     321         return scores.ravel() if scores.shape[1] == 1 else scores
#     322
#
# MemoryError:
